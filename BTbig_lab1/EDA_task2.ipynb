# %% [markdown]
# # **Xử lý và trực quan hóa dữ liệu**

# %% [markdown]
# ## Ôn tập lý thuyết

# %% [markdown]
# ###Trực quan hóa dữ liệu có vai trò gì trong phân tích dữ liệu?

# %% [markdown]
#   Biểu diễn trực quan: Biến dữ liệu thô (số liệu, bảng biểu khó nhìn) thành hình ảnh (biểu đồ, đồ thị) giúp người phân tích dễ nhận ra xu hướng, quy luật và mối quan hệ.
#
#   Phát hiện mẫu (patterns) và xu hướng (trends): Qua biểu đồ (line, bar, scatter, histogram, boxplot...), ta có thể thấy rõ dữ liệu tăng giảm theo thời gian, sự khác biệt giữa các nhóm, hay phân bố của một biến.
#
#   Phát hiện bất thường (outliers) và nhiễu: Những điểm dữ liệu "khác thường" thường rất khó nhận ra khi nhìn bảng số, nhưng trên đồ thị lại nổi bật ngay.
#
#   Hỗ trợ so sánh: Dễ dàng so sánh giữa các nhóm, danh mục hoặc các khoảng giá trị để rút ra kết luận.
#
#   Tăng hiệu quả truyền đạt: Không chỉ giúp nhà phân tích hiểu nhanh hơn, mà còn giúp thuyết phục người khác (quản lý, khách hàng, đối tác) vì hình ảnh trực quan dễ tiếp nhận hơn số liệu khô khan.

# %% [markdown]
# ### Tại sao trực quan hóa quan trọng trong khám phá dữ liệu (EDA)?

# %% [markdown]
# EDA là giai đoạn khám phá, hiểu rõ đặc điểm dữ liệu trước khi xây dựng mô hình. Trực quan hóa giúp:
#
#   Hiểu phân bố dữ liệu: Ví dụ histogram hoặc boxplot giúp xem dữ liệu có lệch (skewed), có phân phối chuẩn hay không.
#
#   Xem mối quan hệ giữa các biến: Scatter plot, heatmap cho thấy sự tương quan (correlation) hoặc mối liên hệ tuyến tính/phi tuyến.
#
#   Phát hiện vấn đề dữ liệu: Thiếu dữ liệu (missing values), dữ liệu ngoại lai, sai lệch – những vấn đề này cần xử lý trước khi phân tích sâu.
#
#   Định hướng phân tích tiếp theo: Sau khi nhìn thấy bức tranh dữ liệu, nhà phân tích sẽ biết nên chọn kỹ thuật thống kê, mô hình hoặc phương pháp tiền xử lý nào phù hợp.

# %% [markdown]
# ###Các loại biểu đồ phổ biến (như histogram, scatter plot, boxplot, bar chart) được sử dụng trong các trường hợp nào?

# %% [markdown]
#   1. Histogram (biểu đồ tần suất)
#
# Dùng khi: Muốn xem phân bố của một biến liên tục (continuous variable).
#
# Ý nghĩa: Cho biết dữ liệu có phân bố chuẩn (normal) không, có lệch trái/phải (skewed) không, có nhiều đỉnh (multimodal) không.
#
# Ví dụ: Phân bố điểm thi của sinh viên, độ tuổi khách hàng, mức thu nhập.
#
#   2. Scatter plot (biểu đồ phân tán)
#
# Dùng khi: Muốn xem mối quan hệ giữa hai biến liên tục.
#
# Ý nghĩa: Thể hiện sự tương quan (tích cực, tiêu cực, hay không tương quan), phát hiện outliers hoặc mô hình phi tuyến.
#
# Ví dụ: Mối quan hệ giữa số giờ học và điểm thi, giữa chiều cao và cân nặng, giữa giá nhà và diện tích.
#
#   3. Boxplot (biểu đồ hộp)
#
# Dùng khi: So sánh phân bố của một biến giữa nhiều nhóm (categorical groups).
#
# Ý nghĩa: Thể hiện trung vị, tứ phân vị (Q1, Q3), độ phân tán, outliers.
#
# Ví dụ: So sánh lương của nhân viên theo giới tính, so sánh điểm thi giữa các lớp, so sánh thời gian giao hàng giữa các khu vực.
#
#   4. Bar chart (biểu đồ cột)
#
# Dùng khi: Biểu diễn dữ liệu phân loại (categorical).
#
# Ý nghĩa: So sánh tần suất hoặc giá trị trung bình giữa các nhóm.
#
# Ví dụ: Số lượng khách hàng theo từng thành phố, doanh số theo từng sản phẩm, số người chọn mỗi loại dịch vụ.

# %% [markdown]
# ###Làm thế nào để chọn loại biểu đồ phù hợp với đặc điểm của dữ liệu (ví dụ: dữ liệu phân loại, dữ liệu số, dữ liệu thời gian)?

# %% [markdown]
# 1. Dữ liệu phân loại (Categorical Data)
#
# Ví dụ: giới tính (Nam/Nữ), ngành học, loại sản phẩm.
# Thường quan tâm đến tần suất hoặc tỷ lệ của từng nhóm.
#
# Bar chart (cột) → so sánh số lượng hoặc giá trị trung bình giữa các nhóm.
#
# Pie chart (tròn) → hiển thị tỷ lệ phần trăm (chỉ nên dùng khi số nhóm ít).
#
# Count plot (bar chart đặc biệt) → đếm số lượng quan sát theo từng nhóm.
#
#
# 2. Dữ liệu số (Numerical / Continuous Data)
#
# Ví dụ: điểm thi, thu nhập, chiều cao, cân nặng.
# Thường quan tâm đến phân bố, xu hướng, mối quan hệ.
#
# Histogram → xem phân bố (chuẩn, lệch trái/phải, nhiều đỉnh).
#
# Boxplot → tóm tắt phân bố, phát hiện outlier, so sánh giữa các nhóm.
#
# Scatter plot → tìm mối quan hệ giữa 2 biến số.
#
# Line chart → khi muốn theo dõi xu hướng biến số liên tục.
#
# 3. Dữ liệu thời gian (Time Series Data)
#
# Ví dụ: doanh số theo tháng, giá cổ phiếu theo ngày, nhiệt độ theo giờ.
# Thường quan tâm đến xu hướng (trend), chu kỳ (seasonality), biến động (fluctuation).
#
# Line chart → biểu diễn xu hướng qua thời gian.
#
# Area chart → tương tự line nhưng nhấn mạnh phần diện tích, thường dùng cho dữ liệu tích lũy.
#
# Candlestick chart → thường dùng trong tài chính (giá mở, cao, thấp, đóng cửa).
#
# 4. Dữ liệu kết hợp (Categorical + Numerical + Time)
#
# Khi dữ liệu vừa có nhóm, vừa có số, vừa có yếu tố thời gian.
#
# Boxplot theo nhóm → so sánh phân bố điểm thi theo giới tính.
#
# Line chart nhiều series → so sánh doanh số nhiều sản phẩm theo thời gian.
#
# Stacked bar chart → doanh thu từng danh mục sản phẩm theo năm.

# %% [markdown]
# ###Sự khác biệt giữa các thư viện trực quan hóa trong Python như Matplotlib, Seaborn và Plotly là gì?

# %% [markdown]
# 1. Matplotlib
#
# Đặc điểm:
# Thư viện nền tảng, “cơ bản nhất” trong Python.
# Cho phép tùy chỉnh cực kỳ chi tiết (màu sắc, font chữ, trục, legend, grid…).
# Hầu hết các thư viện khác (Seaborn, Pandas plot) đều xây dựng dựa trên Matplotlib.
#
# Ưu điểm:
# Linh hoạt, vẽ được hầu hết mọi loại biểu đồ.
# Phù hợp cho báo cáo khoa học, xuất ảnh chất lượng cao.
#
# Nhược điểm:
# Cú pháp dài, nhiều tùy chỉnh thủ công.
# Biểu đồ mặc định “không đẹp mắt”, cần style thêm.
#
#
#
# 2. Seaborn
#
# Đặc điểm:
# Xây dựng dựa trên Matplotlib nhưng cao cấp hơn, trực quan hơn.
# Tích hợp tốt với pandas DataFrame.
# Chuyên để EDA (Exploratory Data Analysis) vì có nhiều biểu đồ thống kê sẵn.
#
# Ưu điểm:
# Cú pháp gọn, dễ dùng.
# Biểu đồ mặc định đẹp, chuyên nghiệp.
# Hỗ trợ biểu đồ thống kê nâng cao (heatmap, violin plot, pairplot…).
#
# Nhược điểm:
# Linh hoạt ít hơn Matplotlib (nếu muốn tùy chỉnh “từng pixel”).
# Chủ yếu cho phân tích, ít dùng trong ứng dụng tương tác.
#
#
# 3. Plotly
#
# Đặc điểm:
# Thư viện hiện đại, hỗ trợ biểu đồ tương tác (zoom, hover, lọc dữ liệu).
# Phù hợp cho dashboard, web app (tích hợp tốt với Dash, Streamlit).
#
# Ưu điểm:
# Biểu đồ đẹp, trực quan, tương tác mạnh.
# Có nhiều loại biểu đồ nâng cao (3D plots, maps, financial candlestick…).
# Xuất sang HTML dễ dàng.
#
# Nhược điểm:
# Hơi nặng hơn, ít dùng cho báo cáo tĩnh.
# Cú pháp mới lạ, khác Matplotlib.

# %% [markdown]
# ###Những nguyên tắc thiết kế nào cần tuân thủ để tạo ra một biểu đồ trực quan hóa dễ hiểu và hiệu quả?

# %% [markdown]
# 1. Xác định mục tiêu rõ ràng
#
# Mỗi biểu đồ cần trả lời một câu hỏi cụ thể: xu hướng, phân bố, so sánh hay mối quan hệ.
#
# Không vẽ quá nhiều thông tin trên cùng một biểu đồ, tránh làm người xem bị rối.
#
# 2. Chọn loại biểu đồ phù hợp
#
# Histogram/Boxplot → phân bố dữ liệu.
#
# Bar chart/Pie chart → so sánh nhóm phân loại.
#
# Scatter plot → mối quan hệ giữa 2 biến số.
#
# Line chart → xu hướng theo thời gian.
# => Chọn sai biểu đồ sẽ gây hiểu nhầm kết quả.
#
# 3. Giữ sự đơn giản và tối giản
#
# Tránh quá nhiều màu sắc, hiệu ứng 3D, chi tiết thừa.
#
# Dùng màu sắc có ý nghĩa (ví dụ: xanh dương = tích cực, đỏ = cảnh báo).
#
# Giữ nền và lưới (grid) nhẹ nhàng, không lấn át dữ liệu.
#
# 4. Làm nổi bật thông tin quan trọng
#
# Sử dụng màu sắc, độ dày đường, hoặc chú thích (annotation) để nhấn mạnh phần dữ liệu quan trọng.
#
# Không nên làm tất cả đều nổi bật, chỉ làm nổi bật thông điệp chính.
#
# 5. Sắp xếp và chuẩn hóa dữ liệu
#
# Nếu dùng bar chart → nên sắp xếp theo giá trị giảm dần để dễ so sánh.
#
# Nếu dữ liệu có đơn vị khác nhau → chuẩn hóa hoặc dùng trục kép cẩn thận.
#
# 6. Thêm nhãn và tiêu đề rõ ràng
#
# Luôn có: tiêu đề, nhãn trục (axis labels), đơn vị đo lường, chú thích (legend nếu cần).
#
# Không để người xem phải đoán dữ liệu đại diện cho cái gì.
#
# 7. Tránh gây hiểu nhầm
#
# Trục Y không nên “cắt bớt” giá trị gốc (0) trừ khi có lý do rõ ràng, vì dễ làm phóng đại sự khác biệt.
#
# Tỷ lệ giữa các cột, vùng, hay vòng tròn phải chính xác với dữ liệu.
#
# 8. Nhất quán
#
# Nếu nhiều biểu đồ trong cùng một báo cáo/dashboard → dùng cùng phong cách, bảng màu, font chữ, định dạng số liệu để người xem dễ theo dõi.

# %% [markdown]
# ###Làm thế nào để tạo một biểu đồ đơn giản như histogram hoặc bar chart bằng Matplotlib? Bạn có thể chia sẻ đoạn code mẫu không?

# %% [markdown]
# Histogram (Biểu đồ tần suất)

# %%
import matplotlib.pyplot as plt

# Dữ liệu điểm thi
scores = [5, 6, 7, 8, 5, 9, 6, 7, 8, 7, 6, 5, 9, 10, 8, 7, 6, 7, 8, 9]

# Vẽ histogram
plt.hist(scores, bins=5, color='skyblue', edgecolor='black')

# Thêm tiêu đề và nhãn
plt.title("Phân bố điểm thi")
plt.xlabel("Điểm")
plt.ylabel("Số lượng sinh viên")

plt.show()

# %% [markdown]
# Bar chart (Biểu đồ cột)

# %%
import matplotlib.pyplot as plt

# Dữ liệu ngành học
majors = ['CNTT', 'Kinh tế', 'Ngôn ngữ', 'Quản trị']
students = [50, 40, 30, 20]

# Vẽ bar chart
plt.bar(majors, students, color='orange')

# Thêm tiêu đề và nhãn
plt.title("Số lượng sinh viên theo ngành học")
plt.xlabel("Ngành học")
plt.ylabel("Số lượng sinh viên")

plt.show()

# %% [markdown]
# ###Làm thế nào để xuất biểu đồ từ Python ra các định dạng như PNG, PDF hoặc HTML để sử dụng trong báo cáo?

# %% [markdown]
# Dùng Matplotlib để xuất ảnh png, pfd

# %%
import matplotlib.pyplot as plt

data = [5,6,7,8,9,7,6,8,9,10,6,5,7,8,9,6,7,8,9,10]

plt.hist(data, bins=5, color='skyblue', edgecolor='black')
plt.title("Histogram điểm thi")
plt.xlabel("Điểm")
plt.ylabel("Số lượng sinh viên")

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/histogram.png", dpi=300)   # lưu file PNG sắc nét
plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/histogram.pdf")            # lưu file PDF (báo cáo/in ấn)

plt.show()

# %% [markdown]
# Dùng plotly để xuất ảnh html

# %%
import plotly.express as px

data = [5,6,7,8,9,7,6,8,9,10,6,5,7,8,9,6,7,8,9,10]

fig = px.histogram(data, nbins=5, title="Histogram điểm thi")
fig.write_html("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/histogram.html")   # Xuất HTML
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Bài làm mẫu

# %% [markdown]
# **Làm quen với các công cụ trực quan hóa dữ liệu về giá nhà**

# %% [markdown]
# ### Chuẩn bị dữ liệu

# %%
import pandas as pd

house_prices = pd.read_csv("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/HousingPrices-Amsterdam-August-2021.csv")
house_prices = house_prices[['Zip', 'Price', 'Area', 'Room']]

# create col priceSqm
house_prices['PriceSqm'] = house_prices['Price'] / house_prices['Area']

# save new file .csv
house_prices.to_csv("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/housePricesData.csv", index=False)

# %%
pd.read_csv("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/housePricesData.csv")
# Out:
#          Zip     Price  Area  Room      PriceSqm
# 0    1091 CR  685000.0    64     3  10703.125000
# 1    1059 EL  475000.0    60     3   7916.666667
# 2    1097 SM  850000.0   109     4   7798.165138
# 3    1060 TH  580000.0   128     6   4531.250000
# 4    1036 KN  720000.0   138     5   5217.391304
# ..       ...       ...   ...   ...           ...
# 919  1097 AE  750000.0   117     1   6410.256410
# 920  1033 CP  350000.0    72     3   4861.111111
# 921  1058 AK  350000.0    51     3   6862.745098
# 922  1095 MB  599000.0   113     4   5300.884956
# 923  1068 JS  300000.0    79     4   3797.468354
#
# [924 rows x 5 columns]

# %% [markdown]
# ### Trực quan hóa dữ liệu với thư viện Matplotlib

# %%
housePrices_sort = house_prices.sort_values(by='Price', ascending=False)
housePrices_sort.head()
# Out:
#          Zip      Price  Area  Room      PriceSqm
# 195  1017 EL  5950000.0   394    10  15101.522843
# 837  1075 AH  5850000.0   480    14  12187.500000
# 305  1016 AE  4900000.0   623    13   7865.168539
# 103  1017 ZP  4550000.0   497    13   9154.929577
# 179  1012 JS  4495000.0   178     5  25252.808989

# %% [markdown]
# Case 1: Basic

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
x = housePrices_sort['Zip'][0:10]
y = housePrices_sort['Price'][0:10]
plt.bar(x, y)
plt.show()

# %% [markdown]
# Case 2: Advanced 1

# %%
plt.figure(figsize=(12,6))
plt.bar(x, y)
plt.title('Top 10 zip có giá nhà cao nhất', fontsize= 15 )
plt.xlabel('Zip code', fontsize = 12)
plt.xticks(fontsize = 10)
plt.ylabel('House prices in millions', fontsize = 12)
plt.yticks(fontsize = 10)
plt.show()

# %% [markdown]
# Case 3: Advanced 2

# %%
fig, ax = plt.subplots(figsize=(40,18))
x = housePrices_sort['Zip'][0:10]
y = housePrices_sort['Price'][0:10]
y1 = housePrices_sort['PriceSqm'][0:10]
plt.subplot(1,2,1)
plt.bar(x,y)
plt.xticks(fontsize=17)
plt.ylabel('House prices in millions', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices',
fontsize=25)
plt.subplot(1,2,2)
plt.bar(x,y1)
plt.xticks(fontsize=17)
plt.ylabel('House prices per sqm', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices per sqm',
fontsize=25)
plt.show()

# %% [markdown]
# ### Trực quan hóa dữ liệu với thư viện Seaborn

# %% [markdown]
# Case 1: Basic

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize= (12,6))
data = housePrices_sort[0:10]
sns.barplot(data= data, x= 'Zip',y = 'Price')
# Out:
# <Axes: xlabel='Zip', ylabel='Price'>
# <Axes: xlabel='Zip', ylabel='Price'>

# %% [markdown]
# Case 2: Advanced 1

# %%
plt.figure(figsize= (12,6))
data = housePrices_sort[0:10]
ax = sns.barplot(data= data, x= 'Zip',y = 'Price')
ax.set_xlabel('Zip code',fontsize = 15)
ax.set_ylabel('House prices in millions', fontsize = 15)
ax.set_title('Top 10 Areas with the highest house prices', fontsize= 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Areas with the highest house prices')

# %% [markdown]
# Case 3: view multiple perspectives at once

# %%
fig, ax = plt.subplots(1, 2,figsize=(40,18))
data = housePrices_sort[0:10]
sns.set(font_scale = 3)
ax1 = sns.barplot(data= data, x= 'Zip',y = 'Price', ax = ax[0])
ax1.set_xlabel('Zip code')
ax1.set_ylabel('House prices in millions')
ax1.set_title('Top 10 Areas with the highest house prices')
ax2 = sns.barplot(data= data, x= 'Zip',y = 'PriceSqm',
ax=ax[1])
ax2.set_xlabel('Zip code')
ax2.set_ylabel('House prices per sqm')
ax2.set_title('Top 10 Areas with the highest price per sqm')
# Out:
# Text(0.5, 1.0, 'Top 10 Areas with the highest price per sqm')

# %% [markdown]
# ## Bài tập thực hành

# %% [markdown]
# ### Dữ liệu về Phân loại chất lượng vượu vang đỏ

# %% [markdown]
# ####Chuẩn bị dữ liệu

# %%
import pandas as pd
wine = pd.read_csv("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/winequality-red.csv")

# %%
wine = wine[['residual sugar', 'alcohol', 'density', 'quality']]

# Tạo biến mới: sugar per alcohol (độ ngọt trên nồng độ cồn)
wine['Sugar_per_Alcohol'] = wine['residual sugar'] / wine['alcohol']

wine.head()
# Out:
#    residual sugar  alcohol  density  quality  Sugar_per_Alcohol
# 0             1.9      9.4   0.9978        5           0.202128
# 1             2.6      9.8   0.9968        5           0.265306
# 2             2.3      9.8   0.9970        5           0.234694
# 3             1.9      9.8   0.9980        6           0.193878
# 4             1.9      9.4   0.9978        5           0.202128

# %%
#Sắp xếp giảm dần theo Residual sugar
wine_sort = wine.sort_values(by='residual sugar', ascending=False)
wine_sort.head()
# Out:
#       residual sugar  alcohol  density  quality  Sugar_per_Alcohol
# 480             15.5      9.2  1.00260        5           1.684783
# 1435            15.4      9.0  1.00369        6           1.711111
# 1434            15.4      9.0  1.00369        6           1.711111
# 1574            13.9     10.5  0.99677        6           1.323810
# 1476            13.8      8.8  1.00242        5           1.568182

# %% [markdown]
# ####Trực quan hóa dữ liệu

# %% [markdown]
# Thư viện Matplotlib

# %%
#Case 1: Basic
plt.figure(figsize=(12,6))
x = wine_sort['quality'][0:10]
y = wine_sort['residual sugar'][0:10]
plt.bar(x, y)
plt.show()

# %%
#Case 2: Advanced 1
plt.figure(figsize=(12,6))
plt.bar(x, y)
plt.title('Top 10 quality wine has highest residual sugar', fontsize= 15 )
plt.xlabel('quality', fontsize = 12)
plt.xticks(fontsize = 10)
plt.ylabel('residual sugar', fontsize = 12)
plt.yticks(fontsize = 10)
plt.show()

# %%
#Case 3: Advanced 2
fig, ax = plt.subplots(figsize=(40,18))

x = wine_sort['quality'][0:10]
y = wine_sort['residual sugar'][0:10]
y1 = wine_sort['Sugar_per_Alcohol'].head(10)

plt.subplot(1,2,1)
plt.bar(x, y, color="salmon")
plt.xticks(fontsize=17)
plt.ylabel('Residual sugar (g/dm³)', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 mẫu rượu có Residual Sugar cao nhất', fontsize=25)


plt.subplot(1,2,2)
plt.bar(x, y1, color="skyblue")
plt.xticks(fontsize=17)
plt.ylabel('Sugar per Alcohol', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 mẫu rượu có tỷ lệ Sugar_per_Alcohol cao nhất', fontsize=25)

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/wineCase3.png", dpi=300)
plt.show()

# %% [markdown]
# Thư viện seaborn

# %%
import seaborn as sns
sugar_sort = wine.sort_values(by='Sugar_per_Alcohol', ascending=False)
#Case 1: Basic
plt.figure(figsize= (12,6))
data = sugar_sort[0:10]
sns.barplot(data= data, x= 'quality',y = 'Sugar_per_Alcohol')
# Out:
# <Axes: xlabel='quality', ylabel='Sugar_per_Alcohol'>

# %%
#Case 2: Advanced 1
plt.figure(figsize= (12,6))
data = sugar_sort[0:10]
ax = sns.barplot(data= data, x= 'quality',y = 'Sugar_per_Alcohol')
ax.set_xlabel('quality',fontsize = 15)
ax.set_ylabel('Sugar_per_Alcohol', fontsize = 15)
ax.set_title('Top 10 mẫu rượu có độ ngọt cao nhất', fontsize= 20)
plt.show()

# %%
#Case 3: view multiple perspectives at once

fig, ax = plt.subplots(1, 2, figsize=(30,12))
data = wine_sort[0:10]
sns.set(font_scale=1.5)


# Biểu đồ 1: residual sugar
ax1 = sns.barplot(data=data, x='quality', y="residual sugar", ax=ax[0])
ax1.set_xlabel("Quality index")
ax1.set_ylabel("Residual Sugar (g/dm³)")
ax1.set_title("Top 10 quality Wines with Highest Residual Sugar")

# Biểu đồ 2: sugar per alcohol
ax2 = sns.barplot(data=data, x ='quality', y="Sugar_per_Alcohol", ax=ax[1])
ax2.set_xlabel("Quality index")
ax2.set_ylabel("Sugar / Alcohol ratio")
ax2.set_title("Top 10 quality Wines with Highest Sugar_per_Alcohol ")

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/wineCase3_Seaborn.png", dpi=300)
plt.show()

# %% [markdown]
# ### Dữ liệu bệnh Đái tháo đường

# %% [markdown]
# ####Chuẩn bị dữ liệu

# %%
df = pd.read_csv("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/pima_diabetes_header.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_sorted = df.sort_values(by='BMI', ascending=False)
diabetes_sorted.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 177            0      129            110             46      130  67.1
# 445            0      180             78             63       14  59.4
# 673            3      123            100             35      240  57.3
# 125            1       88             30             42       99  55.0
# 120            0      162             76             56      100  53.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 177                     0.319   26        1
# 445                     2.420   25        1
# 673                     0.880   22        0
# 125                     0.496   26        1
# 120                     0.759   25        1

# %% [markdown]
# #### Trực quan hóa dữ liệu

# %% [markdown]
# Thư viện Matplotlib

# %%
#Case 1: Basic
plt.figure(figsize=(12,6))
x = diabetes_sorted['Age'][0:10]
y = diabetes_sorted['BMI'][0:10]
plt.bar(x, y)
plt.show()

# %%
#Case 2: Advanced 1
plt.figure(figsize=(12,6))
plt.bar(x, y)
plt.title('Top 10 Ages with BMI highest', fontsize= 15)
plt.xlabel('Age', fontsize = 12)
plt.xticks(fontsize = 10)
plt.ylabel('BMI', fontsize = 12)
plt.yticks(fontsize = 10)
plt.show()

# %%
#Case 3: Advanced 2
fig, ax = plt.subplots(figsize=(40,18))
x = diabetes_sorted['Age'][0:10]
y = diabetes_sorted['Insulin'][0:10]
y1 = diabetes_sorted['BMI'][0:10]
plt.subplot(1,2,1)
plt.bar(x,y)
plt.xlabel('Age', fontsize=25)
plt.xticks(fontsize=20)
plt.ylabel('Insulin', fontsize=25)
plt.title('Top 10 age with highest Insulin', fontsize = 25)

plt.subplot(1,2,2)
plt.bar(x,y1)
plt.xlabel('Age', fontsize=25)
plt.xticks(fontsize=20)
plt.ylabel('BMI', fontsize=25)
plt.title('Top 10 age with highest BMI', fontsize = 25)

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/diabetesCase3.png", dpi=300)
plt.show()

# %% [markdown]
# Thư viện Seaborn

# %%
#Case 1: Basic
plt.figure(figsize= (12,6))
data = diabetes_sorted[0:10]
sns.barplot(data= data, x= 'Age',y = 'BMI')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
#Case 2: Advanced 1
plt.figure(figsize= (12,6))
data = diabetes_sorted[0:10]
ax = sns.barplot(data= data, x= 'Age',y = 'BMI')
ax.set_xlabel('Age',fontsize = 15)
ax.set_ylabel('BMI', fontsize = 15)
ax.set_title('Top 10 age with highest BMI', fontsize= 20)
plt.show()

# %%
#Case 3: view multiple perspectives at once
fig, ax = plt.subplots(1,2 ,figsize=(40,18))
data = diabetes_sorted[0:10]
sns.set(font_scale = 3)
ax1 = sns.barplot(data= data, x= 'Age',y = 'Glucose', ax = ax[0])
ax1.set_xlabel('Age')
ax1.set_ylabel('Glucose')
ax1.set_title('Top 10 age with highest Glucose')
ax2 = sns.barplot(data= data, x= 'Age',y = 'BMI',
ax=ax[1])
ax2.set_xlabel('Age')
ax2.set_ylabel('BMI')
ax2.set_title('Top 10 age with highest BMI')

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/diabetesCase3_Seaborn.png", dpi=300)
plt.show()

# %% [markdown]
# ##EDA tập dữ liệu mua sắm tại siêu thị

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load dataset

# %%
retail = pd.read_excel("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/Online_Retail.xlsx")
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# ### A first look and non-graphical EDA

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail.shape
# Out:
# (541909, 8)

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
retail.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
#Kiểm tra trùng lặp và thiếu dữ liệu
dup = retail.duplicated().sum()
na = retail.isna().sum()
dup = retail.duplicated().sum()
na_per_col = retail.isna().sum()
na_total = retail.isna().sum().sum()
print("Duplicates:", dup)
print("Missing per col:\n", na_per_col)
print("Missing total:", na_total)
# Out:
# Duplicates: 5268
# Missing per col:
#  InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64
# Missing total: 1454

# %% [markdown]
# Nhận xét:
#
# Dữ liệu có 5,268 dòng trùng lặp, cần loại bỏ để tránh làm sai lệch kết quả phân tích.
#
# Có 1,454 giá trị bị thiếu ở cột Description, trong khi các cột khác đều đầy đủ.
#
# Tổng số giá trị thiếu là 1,454, chiếm tỷ lệ nhỏ so với toàn bộ dữ liệu.

# %%
# Xóa dòng trùng lặp
retail = retail.drop_duplicates()

# %%
#Kiểm tra giá trị Quantity và UnitPrice không hợp lệ:
bad_qty = retail.query("Quantity <= 0")
bad_price = retail.query("UnitPrice <= 0")
bad_qty = retail.query("Quantity <= 0")
bad_price = retail.query("UnitPrice <= 0")
print("Rows with Quantity<=0:", len(bad_qty))
print("Rows with UnitPrice<=0:", len(bad_price))
print(bad_qty.head())   # xem vài dòng nếu có
print(bad_price.head())
# Out:
# Rows with Quantity<=0: 10624
# Rows with UnitPrice<=0: 2517
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice CustomerID         Country
# 141 2010-12-01 09:41:00      27.50    14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65    15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65    17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29    17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29    17548.0  United Kingdom
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# ...

# %% [markdown]
# Nhận xét:
#
# Có 10,624 dòng dữ liệu Quantity ≤ 0 → đây thường là các đơn hàng bị hủy hoặc trả lại (return).
#
# Có 2,517 dòng dữ liệu UnitPrice ≤ 0 → đây có thể là lỗi nhập liệu hoặc giao dịch đặc biệt (sample, khuyến mãi, ghi nhận sai).

# %%
# Giữ lại chỉ các dòng hợp lệ
retail = retail[(retail['Quantity'] > 0) & (retail['UnitPrice'] > 0)]

# %%
retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Nhận xét:
#
# Trường dữ liệu CustomerID và Description bị bỏ trống, không hợp lệ

# %%
#Xử lý dữ liệu bị thiếu trong cột CustomerID
retail['CustomerID'] = retail['CustomerID'].fillna('Unknown')
# Loại bỏ dòng thiếu Description
retail = retail.dropna(subset=['Description'])
# Out:
# /tmp/ipython-input-1292616271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail['CustomerID'] = retail['CustomerID'].fillna('Unknown')

# %%
#Kiểm tra giá trị sau khi xử lý

print("Sau làm sạch:", retail.shape)
print("Giá trị thiếu:", retail.isna().sum())
# Out:
# Sau làm sạch: (524878, 8)
# Giá trị thiếu: InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
retail['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
corr = retail.select_dtypes(include='number').corr()
corr = retail.corr(numeric_only=True)
print(corr)
# Out:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.001235
# UnitPrice -0.001235   1.000000

# %% [markdown]
# ### Graphical EDA

# %% [markdown]
# **Using pandas**

# %%
retail['Country'].value_counts().head(10).plot.bar()
plt.title('Top 10 Countries', fontsize=10)
plt.xticks(fontsize=8, rotation=45)            # chỉnh chữ trục X (tên quốc gia)
plt.yticks(fontsize=8)
plt.xlabel('Country',fontsize = 10)
plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/Top10Countries.png", dpi= 300)
plt.show()

# %% [markdown]
# **Using Matplotlib**

# %% [markdown]
# Nhận xét:
#
# Tỷ lệ mua sắm online ở United Kingdom nhiều nhất

# %%
counts = retail['Quantity'].value_counts().head(10)
plt.bar(counts.index, counts.values)
plt.title('Top 10 Quantity')
# Out:
# Text(0.5, 1.0, 'Top 10 Quantity')

# %% [markdown]
# **Using histogram**

# %%
plt.hist(retail['Quantity'], bins=10)
plt.title('Histogram of Quantity')
plt.show()

# %% [markdown]
# Nhận xét:
#
#
# Phần lớn Quantity tập trung quanh giá trị nhỏ, số lượng giao dịch lớn.
#
# Histogram bị lệch mạnh, gần như toàn bộ dữ liệu rơi vào bin đầu tiên.
#
# Có sự tồn tại của giá trị ngoại lai rất lớn khiến biểu đồ khó đọc.

# %% [markdown]
# **Using** **seaborn**

# %%
sns.countplot(x = retail['InvoiceNo'].head(10))
plt.xticks(fontsize = 15)
plt.title('Top 10 InvoiceNo')
# Out:
# Text(0.5, 1.0, 'Top 10 InvoiceNo')

# %% [markdown]
# **Scatterplot using pandas**

# %%
retail.plot.scatter(x='Quantity', y='UnitPrice')
plt.show()

# %% [markdown]
# **Scatterplot using matplotlib**

# %%
plt.scatter('Quantity','UnitPrice', data = retail)
plt.show()

# %%
plt.scatter(retail['Quantity'], retail['CustomerID'])
plt.show()

# %%
plt.plot('Quantity', 'CustomerID', data=retail, linestyle='none', marker='o')
plt.show()

# %% [markdown]
# **Scatterplot using seaborn**

# %%
sns.scatterplot(x='Quantity', y='CustomerID', data=retail)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Quantity', y='UnitPrice', data=retail, hue='Country')

plt.xlim(0, 500)       # giới hạn Quantity để dễ nhìn
plt.ylim(0, 50)        # giới hạn UnitPrice để tránh outlier
plt.legend(title='Country', fontsize=8, title_fontsize=9, loc='upper right')  # chỉnh chữ nhỏ lại
plt.title('Quantity vs UnitPrice by Country')
plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/QuantityUnitPriceByCountry.png", dpi=300)
plt.show()

# %%
sample = retail.sample(1000, random_state=42)

# Vẽ pairplot cho tất cả các cột số
sns.set(style="whitegrid")

g = sns.pairplot(sample, plot_kws={'alpha':0.6, 's':25}, diag_kws={'bins':20})

# Chỉnh kích thước chữ
for ax in g.axes.flatten():
    if ax:  # tránh None
        ax.tick_params(axis='both', labelsize=8)   # chữ trục nhỏ lại

# Tiêu đề chung
g.fig.suptitle("Pairplot for All Numeric Columns (Sample 1000)", fontsize=12, y=1.02)

plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/Pairplot.png", dpi=300)
plt.show()

# %%
sns.pairplot(retail, hue='Country')

# %% [markdown]
# Heatmap

# %%
# Tạo cột Revenue
retail['Revenue'] = retail['Quantity'] * retail['UnitPrice']

# Tính ma trận tương quan cho 3 cột
corr = retail[['Quantity', 'UnitPrice', 'Revenue']].corr()

# Vẽ heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, cmap='Blues', annot=True, fmt=".2f")
plt.title("Correlation Heatmap: Quantity, UnitPrice, Revenue")
plt.show()

# %% [markdown]
# Histograms and distribute

# %%
retail.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# Boxplots and violins

# %%
sns.boxplot(x='Revenue', y = 'Country', data=retail)
plt.show()

# %%
retail.boxplot(by='Country', figsize=(12,8))
plt.show()

# %%
sns.violinplot(x='Quantity', y='Country', data=retail)
plt.show()

# %%
# Top 10 sản phẩm theo Revenue
top_products = retail.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)

# Top 10 quốc gia theo Revenue
top_countries = retail.groupby('Country')['Revenue'].sum().sort_values(ascending=False).head(10)

# Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(40,18))

plt.subplot(1,2,1)
plt.bar(top_products.index, top_products.values)
plt.xticks(rotation=45, ha='right', fontsize=20)
plt.xlabel('Product', fontsize=25)
plt.ylabel('Revenue', fontsize=25)
plt.title('Top 10 Products by Revenue', fontsize=25)

plt.subplot(1,2,2)
plt.bar(top_countries.index, top_countries.values)
plt.xticks(rotation=45, ha='right', fontsize=20)
plt.xlabel('Country', fontsize=25)
plt.ylabel('Revenue', fontsize=25)
plt.title('Top 10 Countries by Revenue', fontsize=25)

plt.tight_layout()
#plt.savefig("/content/drive/MyDrive/Data_Analysis/BTbig_lab1/retailCase.png", dpi=300)
plt.show()
